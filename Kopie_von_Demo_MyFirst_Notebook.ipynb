# %% [markdown]
# <a href="https://colab.research.google.com/github/sputnikera/test/blob/main/Kopie_von_Demo_MyFirst_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
df=pd.read_csv("sample_data/DATA_patients.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      handling  patient employee  handling_id registration_type  \
# 0           1  Registration        1       r1            1             start
# 1           2  Registration        2       r1            2             start
# 2           3  Registration        3       r1            3             start
# 3           4  Registration        4       r1            4             start
# 4           5  Registration        5       r1            5             start
#
#                   time  .order
# 0  2017-01-02 11:41:53       1
# 1  2017-01-02 11:41:53       2
# 2  2017-01-04 01:34:05       3
# 3  2017-01-04 01:34:04       4
# 4  2017-01-04 16:07:47       5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/bina/LB1/DATA/DATA_patients.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      handling  patient employee  handling_id registration_type  \
# 0           1  Registration        1       r1            1             start
# 1           2  Registration        2       r1            2             start
# 2           3  Registration        3       r1            3             start
# 3           4  Registration        4       r1            4             start
# 4           5  Registration        5       r1            5             start
#
#                   time  .order
# 0  2017-01-02 11:41:53       1
# 1  2017-01-02 11:41:53       2
# 2  2017-01-04 01:34:05       3
# 3  2017-01-04 01:34:04       4
# 4  2017-01-04 16:07:47       5

# %%
# URL der CSV-Datei
url = 'https://raw.githubusercontent.com/alendoko/bina/refs/heads/main/LB1/DATA/DATA_patients.csv'

# CSV-Datei direkt laden
df = pd.read_csv(url)

# Vorschau der Datenn
df.head()
# Out:
#    Unnamed: 0      handling  patient employee  handling_id registration_type  \
# 0           1  Registration        1       r1            1             start
# 1           2  Registration        2       r1            2             start
# 2           3  Registration        3       r1            3             start
# 3           4  Registration        4       r1            4             start
# 4           5  Registration        5       r1            5             start
#
#                   time  .order
# 0  2017-01-02 11:41:53       1
# 1  2017-01-02 11:41:53       2
# 2  2017-01-04 01:34:05       3
# 3  2017-01-04 01:34:04       4
# 4  2017-01-04 16:07:47       5
